# %%
import numpy as np
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from qdots_qll.models.models_scratch_for_drafting import SingleQDot3Params
from qdots_qll.models.game import true_pars
import qutip as qt
from functools import partial

# %%
true_pars
# Out:
# Array([ 0.314216,  0.35833 ,  0.053851, -0.333695], dtype=float32)

# %%
from qdots_qll.utils.povms import  sigmas_povm

# %%
Gs = np.array(
    [qt.identity(2), qt.sigmax(), qt.sigmay(), qt.sigmaz()]
) / np.sqrt(2)

# %%
rho0 = qt.rand_dm_ginibre(2).full()

# %%
eta/2
# Out:
# 0.2579869500699283

# %%
(U@Hnazir@U.T).round(3)
# Out:
# array([[-0.258+0.j, -0.   +0.j],
#        [ 0.   +0.j,  0.258+0.j]])

# %%
qt.ket2dm(qt.basis(2, 0))
# Out:
# Quantum object: dims = [[2], [2]], shape = (2, 2), type = oper, isherm = True
# Qobj data =
# [[1. 0.]
#  [0. 0.]]

# %%
m = SingleQDot3Params(sigmas_povm)

gamma_minus = float(true_pars[0])
gamma_plus = float(true_pars[1])
S_minus = float(true_pars[2])
S_plus = float(true_pars[3])
bigOmega = m.Omega
delta = float(m.make_system_hamiltonian()[0, 0])

eta = np.sqrt(delta**2 + bigOmega**2)

# %%
def rho_to_bloch(rho):
    return np.einsum("ijk,kj-> i", Gs, rho).real


def bloch_to_rho(v):
    return np.einsum("ijk,i-> jk", Gs, v)

# %%
def make_U(delta, bigOmega, eta):

    u00 = -(bigOmega / np.sqrt(2)) / (
        np.sqrt(bigOmega**2 + delta * (delta + eta))
    )
    u01 = (delta + eta) / (
        bigOmega * (np.sqrt(1 + (delta + eta) ** 2 / (bigOmega**2)))
    )
    u10 = (np.sqrt(1 + (delta) / (eta))) / (np.sqrt(2))
    u11 = 1 / (np.sqrt(1 + (delta + eta) ** 2 / (bigOmega**2)))
    # u00 = (delta - eta)/(delta) *np.sqrt(delta/eta + 1)
    # u01 = (np.sqrt(1-delta/eta))*(eta/delta + delta/bigOmega)
    # u10 = (np.sqrt(delta/eta + 1))
    # u11 = (delta*bigOmega)/(np.sqrt(eta*bigOmega*(delta**2 + eta*bigOmega)))
    U = np.array([[u00, u01], [u10, u11]])
    return U

# %%
U = make_U(delta, bigOmega, eta)

# %%
Hnazir = delta / 2 * qt.sigmaz() + bigOmega / 2 * qt.sigmax()
Hnazir = Hnazir.full()
Hnazir
# Out:
# array([[ 0.06369668+0.j,  0.25      +0.j],
#        [ 0.25      +0.j, -0.06369668+0.j]])

# %%
rho0tilde = qt.ket2dm(qt.basis(2, 0)).full()
rho0 = U.T @ rho0tilde @ U
v = rho_to_bloch(rho0)

# %%
gamma_plus
# Out:
# 0.35833001136779785

# %%
(U.T @ Hnazir @ U).round(4)
# Out:
# array([[-0.258+0.j, -0.   +0.j],
#        [ 0.   +0.j,  0.258+0.j]])

# %%
def evolve_v(
    v,
    t,
    gamma_minus,
    gamma_plus,
    S_minus,
    S_plus,
    bigOmega,
    eta,
    delta,
):
    # v0, v1, v2, v3 = v

    # v0t = v0
    # v1t = (
    #     v1
    #     * np.cos(
    #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
    #     )
    #     + v2
    #     * np.sin(
    #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
    #     )
    # ) * np.exp(
    #     -1
    #     * (t * (delta**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
    #     / (2 * eta**2)
    # )
    # v2t = (
    #     v2
    #     * np.cos(
    #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
    #     )
    #     - v1
    #     * np.sin(
    #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
    #     )
    # ) * np.exp(
    #     -1
    #     * (t * (delta**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
    #     / (2 * eta**2)
    # )

    # v3t = np.exp(
    #     -1
    #     * (t * (delta**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
    #     / (eta**2)
    # ) * v3 + (
    #     1
    #     - np.exp(
    #         -1
    #         * (t * (delta**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
    #         / (eta**2)
    #     )
       
    # ) * v0*(-(delta**2) * (gamma_minus) + bigOmega**2 * (gamma_plus)) / (
    #     delta**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)
    # )
    # return np.array([v0t, v1t, v2t, v3t])


        # v0, v1, v2, v3 = v

        # v0t = v0
        # v1t = (
        #     v1
        #     * np.cos(
        #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
        #     )
        #     + v2
        #     * np.sin(
        #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
        #     )
        # ) * np.exp(
        #     -1
        #     * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
        #     / (4 * eta**2)
        # )
        # v2t = (
        #     v2
        #     * np.cos(
        #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
        #     )
        #     - v1
        #     * np.sin(
        #         eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
        #     )
        # ) * np.exp(
        #     -1
        #     * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
        #     / (4 * eta**2)
        # )

        # v3t = np.exp(
        #     -1
        #     * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
        #     / (2*eta**2)
        # ) * v3 + (
        #     1
        #     - np.exp(
        #         -1
        #         * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
        #         / (2*eta**2)
        #     )
        
        # ) * v0*(-(bigOmega**2) * (gamma_minus) + bigOmega**2 * (gamma_plus)) / (
        #     bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)
        # )
        # return np.array([v0t, v1t, v2t, v3t])

        v0, v1, v2, v3 = v

        v0t = v0
        v1t = (
            v1
            * np.cos(
                eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
            )
            + v2
            * np.sin(
                eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
            )
        ) * np.exp(
            -1
            * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
            / (4 * eta**2)
        )
        v2t = (
            v2
            * np.cos(
                eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
            )
            - v1
            * np.sin(
                eta * t - (bigOmega**2 * t * ((S_minus) - (S_plus))) / (4 * eta**2)
            )
        ) * np.exp(
            -1
            * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
            / (4 * eta**2)
        )

        v3t = np.exp(
            -1
            * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
            / (2*eta**2)
        ) * v3 + (
            1
            - np.exp(
                -1
                * (t * (bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)))
                / (2*eta**2)
            )
        
        ) * v0*(-(bigOmega**2) * (gamma_minus) + bigOmega**2 * (gamma_plus)) / (
            bigOmega**2 * (gamma_minus) + bigOmega**2 * (gamma_plus)
        )
        return np.array([v0t, v1t, v2t, v3t])

# %%
lambda_v = partial(
    evolve_v,
    gamma_minus=1 * gamma_minus/4 ,
    gamma_plus=1 * gamma_plus /4,
    S_minus=1 * S_minus,
    S_plus=1 * S_plus,
    bigOmega=bigOmega,
    eta=eta,
    delta=delta,
)

times = np.linspace(0, 70, 200)
evolved_rhos = np.array(
    list(
        [
            (
                lambda t: (
                    U.T
                    @ bloch_to_rho(
                        lambda_v(rho_to_bloch(U @ rho0tilde @ U.T), t)
                    )
                    @ U
                )
            )(t)
            for t in times
        ]
    )
)
povms_evolved = jax.vmap(
    lambda t: m.likelihood_particle(true_pars[1:], t, m.vec(rho0tilde))
)(times)
plt.plot(times, evolved_rhos[:, 1, 1], label="map")
plt.plot(times, povms_evolved[:, 4] * 3, label="nazir paper")
plt.legend()
plt.show()

# %%
k = 1

povm_evols = jax.vmap(lambda rho, proj: jnp.trace(rho@proj), in_axes=(0, None))(evolved_rhos,sigmas_povm[k]*3,)


plt.plot(times, povm_evols, label="map")
plt.plot(times, povms_evolved[:, k] * 3, label="nazir paper")
plt.legend()
plt.show()

# %%
sigmas_povm
# Out:
# array([[[ 0.16666667+0.j        , -0.16666667+0.j        ],
#         [-0.16666667+0.j        ,  0.16666667+0.j        ]],
#
#        [[ 0.16666667+0.j        ,  0.16666667+0.j        ],
#         [ 0.16666667+0.j        ,  0.16666667+0.j        ]],
#
#        [[ 0.16666667+0.j        ,  0.        +0.16666667j],
#         [ 0.        -0.16666667j,  0.16666667+0.j        ]],
#
#        [[ 0.16666667+0.j        ,  0.        -0.16666667j],
#         [ 0.        +0.16666667j,  0.16666667+0.j        ]],
#
#        [[ 0.        +0.j        ,  0.        +0.j        ],
#         [ 0.        +0.j        ,  0.33333333+0.j        ]],
#
#        [[ 0.33333333+0.j        ,  0.        +0.j        ],
#         [ 0.        +0.j        ,  0.        +0.j        ]]])

# %%
plt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt
#
# NameError: name 'plt' is not defined

# %%
m.likelihood_particle?
# Out:
# Signature:
# m.likelihood_particle(
#     particle: jaxtyping.Float[Array, 'number_of_parameters'],
#     t: jaxtyping.Float,
#     initial_state: jaxtyping.Complex[Array, 'd**2'],
# ) -> jaxtyping.Float[Array, 'no_outcomes']
# File:      ~/dev/qdots_efficient/qdots_qll/models/models_scratch_for_drafting.py
# Type:      method

# %%
m.__dir__()
# Out:
# ['d',
#  'matrix_d',
#  'positive_eps',
#  'number_of_parameters',
#  'delta',
#  'Omega',
#  'T',
#  'system_hamiltonian',
#  'A',
#  'POVM_arr',
#  'basis_elements',
#  '__module__',
#  '__annotations__',
#  '__init__',
#  'make_system_hamiltonian',
#  'make_liouvillian',
#  'evolve_initial_state_liouvillian',
#  'likelihood_particle',
#  'fim',
#  'generate_data',
#  'qfim',
#  '__doc__',
#  '__abstractmethods__',
#  '_abc_impl',
#  '__abstractvars__',
#  '__abstractclassvars__',
#  '__dataclass_params__',
#  '__dataclass_fields__',
#  '__setattr__',
#  '__delattr__',
#  '__match_args__',
#  'vec',
#  'sprepost',
#  'spre',
#  'spost',
#  '__hash__',
#  '__eq__',
#  '__repr__',
#  '__dict__',
#  '__weakref__',
#  '__new__',
#  '__str__',
#  '__getattribute__',
#  '__lt__',
#  '__le__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__reduce_ex__',
#  '__reduce__',
#  '__getstate__',
#  '__subclasshook__',
#  '__init_subclass__',
#  '__format__',
#  '__sizeof__',
#  '__dir__',
#  '__class__']

# %%
import qutip as qt
import jax
import jax.numpy as jnp

# %%
qt.__version__
# Out:
# '5.0.2'

# %%
zero = qt.basis(2, 0)
one = qt.basis(2, 1)
plus = (qt.basis(2, 0) + qt.basis(2, 1)).unit()
minus = (qt.basis(2, 0) + 1j * qt.basis(2, 1)).unit()

# %%
initial_states = [zero, one, plus, minus]

initial_states_dm = jnp.array([qt.ket2dm(i).full() for i in initial_states])

# %%
import numpy as np

# %%
canonical_povm = (
    np.array(
        [
            qt.identity(2) + qt.sigmax(),
            qt.identity(2) - qt.sigmax(),
            qt.identity(2) + qt.sigmay(),
            qt.identity(2) - qt.sigmay(),
            qt.identity(2) + qt.sigmaz(),
            qt.identity(2) - qt.sigmaz(),
        ]
    )
    / 2
).reshape(-1, 2, 2, 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 13
#       1 canonical_povm = (
#       2     np.array(
#       3         [
#       4             qt.identity(2) + qt.sigmax(),
#       5             qt.identity(2) - qt.sigmax(),
#       6             qt.identity(2) + qt.sigmay(),
#       7             qt.identity(2) - qt.sigmay(),
#       8             qt.identity(2) + qt.sigmaz(),
#       9             qt.identity(2) - qt.sigmaz(),
#      10         ]
#      11     )
#      12     / 2
# ---> 13 ).reshape(-1, 2, 2, 2)
#
# ValueError: cannot reshape array of size 6 into shape (2,2,2)

# %%
qt.identity(2).full()
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 1.+0.j]])

# %%
zero = qt.basis(2, 0)
one = qt.basis(2, 1)
plus = (qt.basis(2, 0) + qt.basis(2, 1)).unit()
minus = (qt.basis(2, 0) + 1j * qt.basis(2, 1)).unit()

initial_states = [zero, one, plus, minus]

initial_states_dm = jnp.array([qt.ket2dm(i).full() for i in initial_states])

# initial_states_bloch = jax.vmap(rho_to_bloch)(initial_states_dm)

# %%
initial_states_dm
# Out:
# Array([[[1. +0.j , 0. +0.j ],
#         [0. +0.j , 0. +0.j ]],
#
#        [[0. +0.j , 0. +0.j ],
#         [0. +0.j , 1. +0.j ]],
#
#        [[0.5+0.j , 0.5+0.j ],
#         [0.5+0.j , 0.5+0.j ]],
#
#        [[0.5+0.j , 0. -0.5j],
#         [0. +0.5j, 0.5+0.j ]]], dtype=complex64)
